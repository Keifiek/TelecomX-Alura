# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



url = "https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json"
datos_main = pd.read_json(url)
datos_main.info()
datos_main.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# ...

# %%
datos_customer = pd.json_normalize(datos_main['customer'])
datos_customer.info()
datos_customer.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 284.0+ KB
#    gender  SeniorCitizen Partner Dependents  tenure
# 0  Female              0     Yes        Yes       9
# 1    Male              0      No         No       9
# 2    Male              0      No         No       4
# 3    Male              1     Yes         No      13
# 4  Female              1     Yes         No       3
# 5  Female              0      No        Yes       9
# 6  Female              1     Yes         No      71
# 7    Male              0     Yes         No      63
# ...

# %%
datos_phone = pd.json_normalize(datos_main['phone'])
datos_phone.info()
datos_phone.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   object
#  1   MultipleLines  7267 non-null   object
# dtypes: object(2)
# memory usage: 113.7+ KB
#   PhoneService MultipleLines
# 0          Yes            No
# 1          Yes           Yes
# 2          Yes            No
# 3          Yes            No
# 4          Yes            No
# 5          Yes            No
# 6          Yes            No
# 7          Yes           Yes
# 8          Yes            No
# 9          Yes           Yes

# %%
datos_internet = pd.json_normalize(datos_main['internet'])
datos_internet.info()
datos_internet.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   object
#  2   OnlineBackup      7267 non-null   object
#  3   DeviceProtection  7267 non-null   object
#  4   TechSupport       7267 non-null   object
#  5   StreamingTV       7267 non-null   object
#  6   StreamingMovies   7267 non-null   object
# dtypes: object(7)
# memory usage: 397.5+ KB
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No         Yes
# 1             DSL             No           No               No          No
# 2     Fiber optic             No           No              Yes          No
# 3     Fiber optic             No          Yes              Yes          No
# ...

# %%
datos_account = pd.json_normalize(datos_main['account'])
datos_account.info()
datos_account.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   object
#  2   PaymentMethod     7267 non-null   object
#  3   Charges.Monthly   7267 non-null   float64
#  4   Charges.Total     7267 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 284.0+ KB
#          Contract PaperlessBilling              PaymentMethod  \
# 0        One year              Yes               Mailed check
# 1  Month-to-month               No               Mailed check
# 2  Month-to-month              Yes           Electronic check
# 3  Month-to-month              Yes           Electronic check
# 4  Month-to-month              Yes               Mailed check
# 5  Month-to-month              Yes    Credit card (automatic)
# ...

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ## **Transformacion de dataframe main**

# %%
datos_main['Churn'] = datos_main['Churn'].map({'Yes' : True, 'No': False})
datos_main['Churn'] = datos_main['Churn'].astype(bool)
datos_main['customerID'] = datos_main['customerID'].astype('string')
datos_main.head(10)
datos_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customerID       7267 non-null   string
#  1   Churn            7267 non-null   bool
#  2   customer         7267 non-null   object
#  3   phone            7267 non-null   object
#  4   internet         7267 non-null   object
#  5   account          7267 non-null   object
#  6   Cuentas_diarias  7267 non-null   float64
# dtypes: bool(1), float64(1), object(4), string(1)
# memory usage: 347.9+ KB

# %% [markdown]
# ## **Transformacion de dataframe customer**

# %%
datos_customer[['Dependents', 'Partner']] = datos_customer[['Dependents', 'Partner']].map(lambda x: True if x == 'Yes' else False)
datos_customer[['Dependents', 'Partner']] = datos_customer[['Dependents', 'Partner']].astype(bool)
datos_customer.info()
datos_customer.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   bool
#  3   Dependents     7267 non-null   bool
#  4   tenure         7267 non-null   int64
# dtypes: bool(2), int64(2), object(1)
# memory usage: 184.6+ KB
#    gender  SeniorCitizen  Partner  Dependents  tenure
# 0  Female              0     True        True       9
# 1    Male              0    False       False       9
# 2    Male              0    False       False       4
# 3    Male              1     True       False      13
# 4  Female              1     True       False       3
# 5  Female              0    False        True       9
# 6  Female              1     True       False      71
# 7    Male              0     True       False      63
# ...

# %% [markdown]
# ## **Transformacion de dataframe phone**

# %%
datos_phone[['PhoneService', 'MultipleLines']] = datos_phone[['PhoneService', 'MultipleLines']].map(lambda x: True if x == 'Yes' else False)
datos_phone[['PhoneService', 'MultipleLines']] = datos_phone[['PhoneService', 'MultipleLines']].astype(bool)
datos_phone.info()
datos_phone.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   bool
#  1   MultipleLines  7267 non-null   bool
# dtypes: bool(2)
# memory usage: 14.3 KB
#    PhoneService  MultipleLines
# 0          True          False
# 1          True           True
# 2          True          False
# 3          True          False
# 4          True          False
# 5          True          False
# 6          True          False
# 7          True           True
# 8          True          False
# 9          True           True

# %% [markdown]
# ## **Transformacion de dataframe internet**

# %%
datos_internet[['OnlineSecurity', 'OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']] = datos_internet[['OnlineSecurity', 'OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']].map(lambda x: True if x == 'Yes' else False)
datos_internet[['OnlineSecurity', 'OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']] = datos_internet[['OnlineSecurity', 'OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']].astype(bool)
datos_internet.info()
datos_internet.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   bool
#  2   OnlineBackup      7267 non-null   bool
#  3   DeviceProtection  7267 non-null   bool
#  4   TechSupport       7267 non-null   bool
#  5   StreamingTV       7267 non-null   bool
#  6   StreamingMovies   7267 non-null   bool
# dtypes: bool(6), object(1)
# memory usage: 99.5+ KB
#   InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 0             DSL           False          True             False
# 1             DSL           False         False             False
# 2     Fiber optic           False         False              True
# 3     Fiber optic           False          True              True
# 4     Fiber optic           False         False             False
# ...

# %% [markdown]
# ##**Transformacion de dataframe account**

# %%
datos_account['PaperlessBilling'] = datos_account['PaperlessBilling'].map({'Yes' : True, 'No': False})
datos_account['PaperlessBilling'] = datos_account['PaperlessBilling'].astype(bool)
datos_account['Charges.Total'] = datos_account['Charges.Total'].replace('[\$,]', '', regex=True)
datos_account['Charges.Total'] = pd.to_numeric(datos_account['Charges.Total'], errors='coerce')
datos_account['Charges.Total'] = datos_account['Charges.Total'].astype(np.float64)
datos_account.info()
datos_account.head(1000)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   bool
#  2   PaymentMethod     7267 non-null   object
#  3   Charges.Monthly   7267 non-null   float64
#  4   Charges.Total     7256 non-null   float64
# dtypes: bool(1), float64(2), object(2)
# memory usage: 234.3+ KB
#            Contract  PaperlessBilling              PaymentMethod  \
# 0          One year              True               Mailed check
# 1    Month-to-month             False               Mailed check
# 2    Month-to-month              True           Electronic check
# 3    Month-to-month              True           Electronic check
# 4    Month-to-month              True               Mailed check
# ..              ...               ...                        ...
# ...

# %% [markdown]
# ## **Crear dataframe unificado post-tranformacion de datos**

# %%
columas_main = datos_main[['customerID', 'Churn']]
dataframe_unificado = pd.concat([columas_main,datos_customer,datos_phone,datos_internet,datos_account],axis=1)
dataframe_unificado
# Out:
#       customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     0002-ORFBO  False  Female              0     True        True       9
# 1     0003-MKNFE  False    Male              0    False       False       9
# 2     0004-TLHLJ   True    Male              0    False       False       4
# 3     0011-IGKFF   True    Male              1     True       False      13
# 4     0013-EXCHZ   True  Female              1     True       False       3
# ...          ...    ...     ...            ...      ...         ...     ...
# 7262  9987-LUTYD  False  Female              0    False       False      13
# 7263  9992-RRAMN   True    Male              0     True       False      22
# 7264  9992-UJOEL  False    Male              0    False       False       2
# 7265  9993-LHIEB  False    Male              0     True        True      67
# 7266  9995-HOTOH  False    Male              0     True        True      63
#
# ...

# %% [markdown]
# ## **Crear columna cuentas diarias**

# %%
datos_main['Cuentas_diarias'] = datos_account['Charges.Monthly']/30
dataframe_unificado['Cuentas_diarias'] = dataframe_unificado['Charges.Monthly']/30

# %%
datos_main.head(10)
# Out:
#    customerID  Churn                                           customer  \
# 0  0002-ORFBO  False  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE  False  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   True  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   True  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   True  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 5  0013-MHZWF  False  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6  0013-SMEOE  False  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 7  0014-BMAQU  False  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 8  0015-UOCOJ  False  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 9  0016-QLJIS  False  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
datos_main[datos_main['Churn'] == False][['Churn', 'Cuentas_diarias']].sort_values(by='Cuentas_diarias', ascending=False)
# Out:
#       Churn  Cuentas_diarias
# 5523  False         3.958333
# 6537  False         3.955000
# 4366  False         3.953333
# 4182  False         3.953333
# 7215  False         3.940000
# ...     ...              ...
# 7233  False         0.623333
# 434   False         0.623333
# 579   False         0.618333
# 7090  False         0.613333
# 4988  False         0.608333
#
# [5174 rows x 2 columns]

# %%
promedio_no_cancelaron = datos_main[datos_main['Churn'] == False]['Cuentas_diarias'].mean()
print(promedio_no_cancelaron)
# Out:
# 2.042170789846669

# %%
datos_main[datos_main['Churn'] == True][['Churn', 'Cuentas_diarias']].sort_values(by='Cuentas_diarias', ascending=False)
# Out:
#       Churn  Cuentas_diarias
# 5998   True         3.945000
# 2053   True         3.926667
# 1620   True         3.915000
# 6581   True         3.873333
# 1027   True         3.855000
# ...     ...              ...
# 861    True         0.633333
# 6559   True         0.631667
# 7058   True         0.630000
# 6759   True         0.628333
# 3538   True         0.625000
#
# [2093 rows x 2 columns]

# %%
dataframe_unificado.info()
dataframe_unificado.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   string
#  1   Churn             7267 non-null   bool
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   bool
#  5   Dependents        7267 non-null   bool
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   bool
#  8   MultipleLines     7267 non-null   bool
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   bool
#  11  OnlineBackup      7267 non-null   bool
#  12  DeviceProtection  7267 non-null   bool
#  13  TechSupport       7267 non-null   bool
#  14  StreamingTV       7267 non-null   bool
#  15  StreamingMovies   7267 non-null   bool
#  16  Contract          7267 non-null   object
# ...

# %%
promedio_cancelaron = datos_main[datos_main['Churn'] == True]['Cuentas_diarias'].mean()
print(promedio_cancelaron)
# Out:
# 2.4420321707278227

# %%
promedios = datos_main.groupby('Churn')['Cuentas_diarias'].mean()

plt.figure(figsize=(6, 4))
promedios.plot(kind='bar', color=['green', 'red'])

plt.title('Promedio de gastos diarios en cuentas')
plt.xlabel('Estado de cuenta')
plt.ylabel('Promedio de gasto en Cuentas Diarias')
plt.xticks(ticks=[0, 1], labels=['No ', 'Sí'], rotation=0)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %%
genero_churn = dataframe_unificado.groupby(['gender', 'Churn']).size().unstack()

genero_churn.plot(kind='bar', stacked=False, color=['green', 'red'])
plt.title('Cancelación por Género')
plt.xlabel('Género')
plt.ylabel('Número de Clientes')
plt.xticks(rotation=0)
plt.legend(title='Churn')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
contract_churn = dataframe_unificado.groupby(['Contract', 'Churn']).size().unstack()

contract_churn.plot(kind='bar', stacked=False, color=['green', 'red'])
plt.title('Cancelación por Tipo de Contrato')
plt.xlabel('Tipo de Contrato')
plt.ylabel('Número de Clientes')
plt.xticks(rotation=0)
plt.legend(title='Churn')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
metodo_pago_churn = dataframe_unificado.groupby(['PaymentMethod', 'Churn']).size().unstack()

metodo_pago_churn.plot(kind='barh', stacked=False, color=['green', 'red'])
plt.title('Cancelación por Metodo de Pago')
plt.xlabel('Número de Clientes')
plt.ylabel('Metodo de Pago')
plt.xticks(rotation=1)
plt.legend(title='Churn')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
totales = dataframe_unificado.groupby('Churn')['Charges.Total'].sum()
print(totales)
plt.figure(figsize=(6, 4))
totales.plot(kind='bar', color=['green', 'red'])

plt.title('Total de gastos en cuentas')
plt.xlabel('Estado de cuenta')
plt.ylabel('Total gastado')
plt.xticks(ticks=[0, 1], labels=['No ', 'Sí'], rotation=0)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# Churn
# False    13193241.80
# True      3355040.05
# Name: Charges.Total, dtype: float64

# %%
totales = dataframe_unificado.groupby('Churn')['Charges.Total'].mean()
print(totales)
plt.figure(figsize=(6, 4))
totales.plot(kind='bar', color=['green', 'red'])

plt.title('Total de gastos en cuentas')
plt.xlabel('Estado de cuenta')
plt.ylabel('Total gastado')
plt.xticks(ticks=[0, 1], labels=['No ', 'Sí'], rotation=0)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# Churn
# False    2555.344141
# True     1602.981390
# Name: Charges.Total, dtype: float64

# %%
promedio_tiempo = dataframe_unificado.groupby('Churn')['tenure'].mean()
print(dataframe_unificado['tenure'].mean())
print(promedio_tiempo)
plt.figure(figsize=(6, 4))
promedio_tiempo.plot(kind='bar', color=['green', 'red'])

plt.title('Tiempo de servicio')
plt.xlabel('Estado de cuenta')
plt.ylabel('Promedio de tiempo')
plt.xticks(ticks=[0, 1], labels=['No ', 'Sí'], rotation=0)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# 32.34649786707032
# Churn
# False    37.569965
# True     19.433827
# Name: tenure, dtype: float64

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ## **Introduccion**
#
#
# En este analisis se busca dar con la razon del porque la empresa Telecom X se encuentra actualmente sufriendo una alta evasion de clientes tambien conocida como Churn.
# Para lograr este objetivo la empresa a solicitado una analisis de datos, proporcionando datos de los clientes asi como diferentes caracteristicas para contrastar entre si, como puede ser el genero, el tiempo contratado o el pago total generado, entre otros.

# %% [markdown]
# ## **Limpieza y Tratamiento de Datos**

# %% [markdown]
# ### **Importacion de datos**
#
# Los datos fueron proporcionados por medio de un archivo JSON por lo cual se decidio usar la ayuda de la libreria pandas para representar los datos en un dataframe previo a la limpieza y tratamiento de los datos.
# Lo primero que se observo al intentar generar el dataframe con ayuda de la libreria pandas es que teniamos varios niveles dentro de nuestro archivo JSON por lo cual debiamos normalizar estos niveles en diferentes dataframes.

# %% [markdown]
# #### **Normalizacion**
# Despues de notar que columnas de nuestro dataframe deberiamos de normalizar procedimoa a generar estos nuevos dataframes obteniendo 5 dataframes diferentes con el principal incluido.

# %% [markdown]
# ### **Limpieza y tranformacion de datos**

# %% [markdown]
# #### **Limpieza**
# En este caso no fue necesario hacer muchos pasos en la limpieza de los datos puesto que parecian seguir en su mayoria formatos establecidos, sin embargo en la columa de valor total me di cuenta que habia algunos valores con espacios que posteriormente daria problemas al intentar convertir a un tipo float por lo cual que hico una tratamiento preliminar a la transformacion

# %% [markdown]
# #### **Transformacion de Datos**
# Para este paso si hubo bastante carga de cosas por realizar puesto que en casi todos los dataframes generados los tipos de datos de las columnas eran en su mayoria de tipo object y no tenian los tipos bien definidos, para arreglar esto primero converti algunos datos que note que eran a grandes rasgos booleanos.

# %% [markdown]
# ##### **Booleanos**
# En el dataframe encontramos varios tipos de datos que a simple vista notamos que pueden ser considerados booleanos puesto que solo tienen dos tipos de valores "Yes" y "No" para esto hicimos un map a todos estos valores para cambiarlos a True o False y posteriormente hicimos que pandas lo detectara como un boolano con ayuda de la funcion astype.

# %% [markdown]
# ##### **Flotantes**
# En este caso el unico que no detecto como flotante fue la columna de gasto total por lo cual hice algunos cambios como quitar las comas, los espacios y hacerlo de manera regresiva con un regex en caso de que se hubiera ido un espacio al inicio y otro al final, los datos quedaron estandarizados como los demas flotantes.

# %% [markdown]
# ##### **String**
#
# En este caso no hubo mucho que hacer puesto que a pesar de que aplicara el astype con str el pandas lo seguia reconociendo como un object por lo cual decidi usar string solo para recordarlo pero no fue del todo necesario posteriormente.

# %% [markdown]
# ##### **Dataframes**
# Como se menciono durante la importacion se ocuparon crear varios dataframes para poder normalizar algunas columnas sin embargo me di cuenta que esto generaria problematicas para el analisis posterior por lo cual revise y todos los dataframes geenrados tenian una correspondencia de 1 a 1, es decir que teniamos la misma cantidad de registros, por lo cual decidi concatenar todos los dataframes generados obteniendo un nuevo dataframe unificado que era lo que me interesaba conseguir al inico.

# %% [markdown]
# ## **Analisis Exploratorio de los datos**

# %% [markdown]
# ### **Visualizacion**
#
# Para la visualizacion de los datos me ayude de la libreria matplotlib para generar graficos, en este caso debido a la naturaleza del problema de realizar comparaciones contra una variable como lo es Church decidi que la mejor manera de observar estas comparaciones eran con graficos de barras.

# %% [markdown]
# ### **Graficos**
# Los graficos fueron desde comparar recuentos de variables categoricas como lo puede ser el genero o el tipo de contrato de cada tipo de clientes a representar por medio de promedios o totales de las variables numericas como el tiempo que llevan los clientes con el servicio o el total que gastaron en los servicios

# %% [markdown]
# ## **Conclusiones**

# %% [markdown]
# ### **Cancelacion en base a gastos diarios**
# Una de las cosas que se pudieron observar al comparar estas secciones es que las personas que mas ahan estado cancelando sus servicio eran las que en promedio gastaban mas dinero aproximadamente 25% mas que los que decidieron no cancelar

# %% [markdown]
# ### **Cancelacion en basa al genero**
# En este caso no se pudo notar una diferencia sustancial o relevante en el tipo de genero en erlacion al estado de cancelacion de la cuenta

# %% [markdown]
# ### **Cancelacion en base al tipo de contrato**
# Aqui sin notamos algo que podria ser relevante para nuestro problema y es que la gran mayoria de clientes que cancelan su servicio tienen un tipo de contrato mes a mes, el resto de los tipos de contrato no tienen un monto de cancelaciones relevantes para nuestro problema.

# %% [markdown]
# ### **Cancelacion por metodo de pago**
# En este caso 3 de 4 metodos de pago tienen un nivel similar en cuanto a cancelaciones se refiere, sin embargo el 4 metodo el cual es Electronic Check tiene casi el doble de cancelaciones que el resto de los metodos.

# %% [markdown]
# ## **Recomendaciones**
# Se recomienda analizar si es posible generar estrategias para que los usuarios opten por elegir un metodo de contrato diferentes al de mes por mes, tal vez explicandoles que esto puede llevar a mayor gasto diario que otros planes.
# De igual manera analizar porq estas personas tienen mayor promedio de gastos diarios. tal vez el meotodo de pago electronico les esta generando cargos extras que de igual manera deberian de analizarse.
